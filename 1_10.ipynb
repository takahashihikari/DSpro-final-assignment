# %%
from bs4 import BeautifulSoup
import requeｓts

# %%
import sqlite3

# %%
sql_create_table_Google_news_1_15 = 'CREATE TABLE Google_news_1_15(news_name text);'
sql_create_table_Nittere_news_1_15 = 'CREATE TABLE Nittere_news1_15(news_name text);'
sql_create_table_Google_news_1_16 = 'CREATE TABLE Google_news_1_16(news_name text);'
sql_create_table_Nittere_news_1_16 = 'CREATE TABLE Nittere_news1_16(news_name text);'
cur.execute(sql_create_table_Google_news_1_15)
cur.execute(sql_create_table_Nittere_news_1_15)
cur.execute(sql_create_table_Google_news_1_16)
cur.execute(sql_create_table_Nittere_news_1_16)

# %%
db_name = 'repo.sqlite'
con = sqlite3.connect(db_name)
cur = con.cursor()

con.close()

# %%
url = "https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFZxYUdjU0FtcGhHZ0pLVUNnQVAB?hl=ja&gl=JP&ceid=JP%3Aja"
r = requests.get(url)

# %%
html_soup = BeautifulSoup(r.text, 'html.parser')

# %%
Google_news_name_list_1_15 = []
a_all = html_soup.find_all('a', attrs={ 'class': 'gPFEn' })
for news_name in a_all:
  news_name = news_name.string
  Google_news_name_list_1_15.append(news_name)

Google_news_name_list_1_15 = list(zip(Google_news_name_list_1_15))

# %%
Google_news_name_list_1_16 = []
a_all = html_soup.find_all('a', attrs={ 'class': 'gPFEn' })
for news_name in a_all:
  news_name = news_name.string
  Google_news_name_list_1_16.append(news_name)

Google_news_name_list_1_16 = list(zip(Google_news_name_list_1_16))

# %%
for element in Google_news_name_list_1_16:
  print(element)
# Out:
# ('米大統領選 共和党 候補者選び初戦 きょうアイオワ州 党員集会 | NHK',)
# ('アメリカ大統領選挙、トランプ氏優勢・ヘイリー氏上昇 16日昼にも大勢判明',)
# ('【今朝の５本】仕事を始める前に読んでおきたい厳選ニュース',)
# ('アイオワ州の民主党員、「初戦」奪われ疎外感',)
# ('韓国は「別の国」、北朝鮮の金総書記が演説 憲法改正へ',)
# ('米専門家「金正恩委員長、戦争決めたようだ…朝鮮戦争直前以来最も危険」（ハンギョレ新聞） - Yahoo!ニュース',)
# ('正恩氏 統一は「もはや不可能」',)
# ('北朝鮮 キム総書記 憲法改正を指示“韓国を第1の敵対国” | NHK',)
# ('石川県が犠牲者23人の氏名、死因など公表へ 能登半島地震',)
# ('10歳から93歳までの男女 能登半島地震で犠牲者の名前を石川県が初公表（石川テレビ） - Yahoo!ニュース',)
# ('【能登半島地震】死者23人の氏名公表 遺族の同意得られた分から 石川県',)
# ('お別れも ままならず 火葬場被害、身元確認遅れ：北陸中日新聞Web',)
# ('あの日救えなかった命 神戸でとんかつ店経営の父が毎年続けた追悼 遺志継ぐ息子「今年も続けるで」',)
# ('阪神大震災で父弟失う 能登へ思い - Yahoo!ニュース',)
# ('【阪神・淡路震災から29年】「死ぬかもしれないときに何もしなかった」目の前で失った家族「死のうと思っていた」救えなかった罪の意識 「幸せに生きている方が喜んでくれるかもしれない」向き合い続けた29年',)
# ('子どもは絶対3人欲しいと願った 母と妹たちへ、残された姉の29年：朝日新聞デジタル',)
# ('16日 日本海側は大雪・高波・交通障害に警戒 太平洋側も真冬並みの厳しい寒さ(気象予報士 小野 聡子 2024年01月16日)',)
# ('日本海側は一日で積雪急増 雪質変化に住民困惑 除雪諦めも【スーパーJチャンネル】(2024年1月15日)',)
# ('16日 北日本と北陸は猛ふぶき警戒 - Yahoo!ニュース',)
# ('新潟 長野 関東北部 １６日夕方にかけ山沿い中心に大雪警戒｜NHK 首都圏のニュース',)
# ...

# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_insert_many = "INSERT INTO Google_news_1_15 VALUES (?);"
cur.executemany(sql_insert_many, Google_news_name_list_1_15)
con.commit()
con.close()

# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_insert1 = "INSERT INTO Nittere_news1_15 VALUES ('アイスランドで再び噴火');"
sql_insert2 = "INSERT INTO Nittere_news1_15 VALUES ('東久留米市で降りたタクシーに男性はねられ死亡');"
sql_insert3 = "INSERT INTO Nittere_news1_15 VALUES ('ヤマト運輸を装い十人切りつけ腕時計盗み逃走');"
sql_insert4 = "INSERT INTO Nittere_news1_15 VALUES ('イスラエルとハマス戦闘開始から100日  2万3000人以上死亡');"
sql_insert5 = "INSERT INTO Nittere_news1_15 VALUES ('イスラエル・テルアビブ  ”ハマスの地下トンネル”再現した展示物公開');"
sql_insert6 = "INSERT INTO Nittere_news1_15 VALUES ('大学入学共通テスト  2日目終了');"
sql_insert7 = "INSERT INTO Nittere_news1_15 VALUES ('発生から二週間 輪島市長  避難所で二次避難呼びかけ');"
sql_insert8 = "INSERT INTO Nittere_news1_15 VALUES ('発生二週間  約二万人の避難生活続く');"
sql_insert9 = "INSERT INTO Nittere_news1_15 VALUES ('岸田首相  石川県の被災地視察  1000億円超の追加支援表明');"
sql_insert10 = "INSERT INTO Nittere_news1_15 VALUES ('被災した人の心のケア  「警視庁きずな隊」石川県の避難所の訪問');"
sql_insert11 = "INSERT INTO Nittere_news1_15 VALUES ('家屋倒壊・低体温症などに十分注意  被災地で明日にかけ大雪のおそれ');"
sql_insert12 = "INSERT INTO Nittere_news1_15 VALUES ('10分前には男性刺される事件も  茨城で女性刺される  連続殺人未遂か');"
sql_insert13 = "INSERT INTO Nittere_news1_15 VALUES ('男性(49)死亡  スタバ発砲で男逃走中  警戒続く');"
sql_insert14 = "INSERT INTO Nittere_news1_15 VALUES ('米大統領戦 アイオワ州で初戦  共和党候補者選び トランプ氏圧勝なるか');"
sql_insert15 = "INSERT INTO Nittere_news1_15 VALUES ('北朝鮮「成功」と主張  ”極超音速”中距離弾道ミサイル試験発射');"
cur.execute(sql_insert1)
cur.execute(sql_insert2)
cur.execute(sql_insert3)
cur.execute(sql_insert4)
cur.execute(sql_insert5)
cur.execute(sql_insert6)
cur.execute(sql_insert7)
cur.execute(sql_insert8)
cur.execute(sql_insert9)
cur.execute(sql_insert10)
cur.execute(sql_insert11)
cur.execute(sql_insert12)
cur.execute(sql_insert13)
cur.execute(sql_insert14)
cur.execute(sql_insert15)
con.commit()
con.close()

# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_insert_many = "INSERT INTO Google_news_1_16 VALUES (?);"
cur.executemany(sql_insert_many, Google_news_name_list_1_16)
con.commit()
con.close()

# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_insert1 = "INSERT INTO Nittere_news1_16 VALUES ('スタバで発砲 男性殺害  暴力団幹部の男を指名手配');"
sql_insert2 = "INSERT INTO Nittere_news1_16 VALUES ('台湾「中国が金で誘惑」と避難  ナウル 台湾と断行');"
sql_insert3 = "INSERT INTO Nittere_news1_16 VALUES ('去年1年間の倒産件数  前年より3割以上増加');"
sql_insert4 = "INSERT INTO Nittere_news1_16 VALUES ('埼玉・川口市でタクシー強盗  運転手から現金を・・・おとといにも');"
sql_insert5 = "INSERT INTO Nittere_news1_16 VALUES ('SMILE-UP.について当事者の会  「被害者と向き合っているといえるのか」');"
sql_insert6 = "INSERT INTO Nittere_news1_16 VALUES ('JR京葉線 廃止計画を一転  早朝の快速 引き続き運行');"
sql_insert7 = "INSERT INTO Nittere_news1_16 VALUES ('“ビックモーター”枯れた街路樹  都が原状回復');"
sql_insert8 = "INSERT INTO Nittere_news1_16 VALUES ('ビックモーター問題で. 損保ジャパンに業務改善命令へ');"
sql_insert9 = "INSERT INTO Nittere_news1_16 VALUES ('能登半島地震 犠牲者23人の氏名 県が初公表');"
sql_insert10 = "INSERT INTO Nittere_news1_16 VALUES ('”政治とカネ”で岸田首相 菅氏・麻生氏と相次ぎ会談');"
sql_insert11 = "INSERT INTO Nittere_news1_16 VALUES ('共和党候補者選びスタートへ アイオワ州でトランプ氏独走');"
sql_insert12 = "INSERT INTO Nittere_news1_16 VALUES ('1能登半島地震  複数の海底活断層が関連の可能性');"
sql_insert13 = "INSERT INTO Nittere_news1_16 VALUES ('被災地に「吹雪」のおそれ  積雪での「倒壊」注意');"
sql_insert14 = "INSERT INTO Nittere_news1_16 VALUES ('家に土砂が…  妻子4人の葬儀で');"

cur.execute(sql_insert1)
cur.execute(sql_insert2)
cur.execute(sql_insert3)
cur.execute(sql_insert4)
cur.execute(sql_insert5)
cur.execute(sql_insert6)
cur.execute(sql_insert7)
cur.execute(sql_insert8)
cur.execute(sql_insert9)
cur.execute(sql_insert10)
cur.execute(sql_insert11)
cur.execute(sql_insert12)
cur.execute(sql_insert13)
cur.execute(sql_insert14)

con.commit()
con.close()

# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_select = 'SELECT * FROM Google_news_1_15;'
cur.execute(sql_select)

for r in cur:
  print(r)

con.close()
# Out:
# ('台湾総統選で中国が敵視する頼清徳氏勝利、英国も本気で心配し始めた中台情勢 もし中国が武力に訴えたら…台湾有事で死者50万人、世界市場は2兆ドル縮小(1/5)',)
# ('「台湾統一を実現する」中国外相 - Yahoo!ニュース',)
# ('総統当選の頼清徳氏、超党派議連の古屋圭司会長と面会…当選翌日で「台日協力に深い思いがある」',)
# ('＜社説＞台湾総統に頼氏 地域の安定へ対話推進を',)
# ('米大統領選 共和党候補者選び初戦 アイオワ州 各候補支持訴え | NHK',)
# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_select = 'SELECT * FROM Google_news_1_16;'
cur.execute(sql_select)

for r in cur:
  print(r)

con.close()
# Out:
# ('台湾総統選で中国が敵視する頼清徳氏勝利、英国も本気で心配し始めた中台情勢 もし中国が武力に訴えたら…台湾有事で死者50万人、世界市場は2兆ドル縮小(1/5)',)
# ('「台湾統一を実現する」中国外相 - Yahoo!ニュース',)
# ('総統当選の頼清徳氏、超党派議連の古屋圭司会長と面会…当選翌日で「台日協力に深い思いがある」',)
# ('＜社説＞台湾総統に頼氏 地域の安定へ対話推進を',)
# ('米大統領選 共和党候補者選び初戦 アイオワ州 各候補支持訴え | NHK',)
# ('【今朝の５本】仕事を始める前に読んでおきたい厳選ニュース',)
# ('【アメリカ大統領選】共和党候補者選び トランプ前大統領「安倍元首相は…」',)
# ('アイオワ州の民主党員、「初戦」奪われ疎外感',)
# ('帰省先の珠洲市で土砂崩れ、妻子４人を失った男性「いつまでも一緒にいたかった」…悲しみこらえ告別式',)
# ('「怖かったね、ごめんね」 土砂にのまれた妻子4人の葬儀で涙（毎日新聞） - Yahoo!ニュース',)
# ('土砂にのまれた妻子の葬儀で涙 (2024年1月14日掲載) - ライブドアニュース',)
# ('「やっと出てきてくれた」行方不明の漁師、遺体で見つかる 妻と子のもとへ：中日新聞Web',)
# ('青森は半日で40センチ以上の雪 明日16日にかけて北海道、東北、北陸は大雪に警戒(気象予報士 日直主任 2024年01月15日)',)
# ('【大雪情報】日本海側や北海道は積雪急増・視界不良に警戒（15日7時更新）',)
# ('15日夜から16日夕方にかけて県内北部で大雪に注意｜下野新聞 SOON',)
# ('北陸など 15日から警報級大雪恐れ - Yahoo!ニュース',)
# ('共通テスト 不正行為で4人失格 - Yahoo!ニュース',)
# ('カンニングなどの不正行為で受験生4人が失格 大学入学共通テスト2日間の日程終了｜TBS NEWS DIG',)
# ('生物、代ゼミ問題分析 大学入学共通テスト [共通テスト問題分析2024]',)
# ('大学入学共通テストの「倫理、政治・経済」 教科書ではほとんど扱われない「吉野源三郎」が登場（高校生新聞オンライン） - Yahoo!ニュース',)
# ...

# %%
con = sqlite3.connect(db_name)
cur = con.cursor()
sql_select = 'SELECT * FROM Nittere_news1_16;'
cur.execute(sql_select)

for r in cur:
  print(r)

con.close()
# Out:
# ('スタバで発砲 男性殺害  暴力団幹部の男を指名手配',)
# ('台湾「中国が金で誘惑」と避難  ナウル 台湾と断行',)
# ('去年1年間の倒産件数  前年より3割以上増加',)
# ('埼玉・川口市でタクシー強盗  運転手から現金を・・・おとといにも',)
# ('SMILE-UP.について当事者の会  「被害者と向き合っているといえるのか」',)
# ('JR京葉線 廃止計画を一転  早朝の快速 引き続き運行',)
# ('“ビックモーター”枯れた街路樹  都が原状回復',)
# ('ビックモーター問題で. 損保ジャパンに業務改善命令へ',)
# ('能登半島地震 犠牲者23人の氏名 県が初公表',)
# ('”政治とカネ”で岸田首相 菅氏・麻生氏と相次ぎ会談',)
# ('共和党候補者選びスタートへ アイオワ州でトランプ氏独走',)
# ('1能登半島地震  複数の海底活断層が関連の可能性',)
# ('被災地に「吹雪」のおそれ  積雪での「倒壊」注意',)
# ('家に土砂が…  妻子4人の葬儀で',)
# ('スタバで発砲 男性殺害  暴力団幹部の男を指名手配',)
