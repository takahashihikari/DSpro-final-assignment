# %%
from bs4 import BeautifulSoup
import requeｓts

# %%
url = "https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFZxYUdjU0FtcGhHZ0pLVUNnQVAB?hl=ja&gl=JP&ceid=JP%3Aja"
r = requests.get(url)

# %%
html_soup = BeautifulSoup(r.text, 'html.parser')

# %%
news_name_list = []
a_all = html_soup.find_all('a', attrs={ 'class': 'gPFEn' })
for news_name in a_all:
  news_name = news_name.string
  news_name_list.append(news_name)

# %%
for element in news_name_list:
  print(element)
# Out:
# 北朝鮮軍が黄海に200発余砲撃 韓国軍が発表 被害なし | NHK
# 韓国・延坪島で住民に避難命令 韓国軍「北朝鮮が島などに向け200発あまりの射撃を行った」（日テレNEWS NNN） - Yahoo!ニュース
# 【速報】韓国・延坪島で住民に避難命令 韓国軍「北朝鮮が島などに向け200発あまりの射撃を行った」
# 中国、北朝鮮砲撃の非難避ける 「各方面は冷静と抑制を」
# 【能登半島地震】輪島港に異変、水深が浅くなった？ 海底隆起か、漁業への影響懸念：北陸中日新聞Web
# もう涙も出ない 支援遅れた集落 - Yahoo!ニュース
# 【普段は他人でも「みんなで励まし合って」】避難所にお年寄りをおんぶする若者の姿 未曾有の被害に見舞われた石川・輪島市【能登半島地震】
# 【能登半島地震・珠洲ルポ】「水平線の両側からわーっと」 津波被害、徐々に明らかに：北陸中日新聞Web
# 被災地 明日6日～警報級大雨 7日～警報級大雪恐れ 新たな災害に警戒(気象予報士 石榑 亜紀子 2024年01月05日)
# 8日被災地は大雪か 暖取る工夫を - Yahoo!ニュース
# 【令和6年能登半島地震】北陸は三連休以降も雨の降りやすい天気
# 能登半島の被災地 あすから雨 あさってには雪か 土砂災害注意
# 石川県の避難所でインフルやコロナ感染者増加
# 【冬の避難生活】「低体温症」に注意 スマホを少しでも長く使うためには
# エコノミー症候群や感染症の予防法 避難長期化で心配される蔓延に注意
# “避難所生活 集団感染に注意 できる範囲で感染対策を”
# 首相、再選戦略描けず 政局展望 - Yahoo!ニュース
# 【冒頭発言】自民、来週に政治刷新本部 首相表明 改革案、月内取りまとめ 規正法改正「必要なら提出」
# 岸田首相コメント｜NHK NEWS WEB
# 岸田首相に追い込まれた最大派閥・安倍派が進める逆襲の準備 野党に岸田氏の医師会献金問題を追及させ、主流3派の大炎上を狙うか（NEWSポストセブン） - Yahoo!ニュース
# 北九州の火災1日経っても鎮火せず 35店焼損、焼きうどん発祥店も：朝日新聞デジタル
# 小倉の火災 24h時点で鎮火至らず - Yahoo!ニュース
# 「鳥町食道街」火災 一帯の３５店舗が被災
# ...
